# %%
pip install opencv-python

# %%
pip install opencv-contrib-python

# %%
pip install pillow

# %%
pip install scikit-image

# %%
pip install mahotas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 20.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ###examples 1

# %%
import cv2

# Replace 'path/to/image.jpg' with the actual path to your image file
image_path = '/Users/shinchan/Downloads/tiger (1).jpg'

# Read the image using 'imread' function
image = cv2.imread(image_path)

# Check if the image was successfully read
if image is not None:
    print("Image loaded successfully.")
else:
    print("Failed to load the image.")
# Out:
# Failed to load the image.

# %%
import cv2
import imutils

# %%
from google.colab import files

# Upload image file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e9a2fb4-40a4-4d7d-824d-64ad3331dcee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e9a2fb4-40a4-4d7d-824d-64ad3331dcee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Assuming the uploaded file is named 'tiger (1).jpg'
with open('tiger (1).jpg', 'wb') as f:
    f.write(uploaded['tiger (1).jpg'])

# %%
import cv2

image_path = 'tiger (1).jpg'
image = cv2.imread(image_path)

if image is not None:
    print("Image loaded successfully.")
else:
    print("Failed to load the image.")
# Out:
# Image loaded successfully.

# %%
image.shape
# Out:
# (667, 1000, 3)

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
image
# Out:
# array([[[191, 205, 224],
#         [191, 205, 224],
#         [191, 205, 224],
#         ...,
#         [ 50, 116, 135],
#         [ 50, 116, 135],
#         [ 49, 115, 134]],
#
#        [[187, 201, 220],
#         [187, 201, 220],
#         [187, 201, 220],
#         ...,
#         [ 51, 117, 136],
#         [ 50, 116, 135],
#         [ 50, 116, 135]],
#
#        [[179, 194, 213],
#         [179, 194, 213],
#         [179, 194, 213],
#         ...,
#         [ 52, 118, 137],
#         [ 51, 117, 136],
#         [ 50, 116, 135]],
#
#        ...,
#
#        [[ 32,  53,  74],
#         [ 38,  58,  83],
#         [ 49,  84, 110],
#         ...,
#         [145, 111,  82],
#         [146, 112,  83],
#         [147, 113,  84]],
#
#        [[ 17,  41,  61],
#         [ 37,  57,  82],
#         [ 52,  85, 111],
#         ...,
#         [145, 111,  82],
#         [147, 113,  84],
#         [148, 114,  85]],
#
#        [[ 20,  44,  64],
#         [ 46,  66,  91],
#         [ 50,  80, 105],
# ...

# %%
#resizing the image
resizeimg = imutils.resize(image,width = 120)

# %%
resizeimg
# Out:
# array([[[164, 183, 202],
#         [161, 179, 201],
#         [153, 166, 185],
#         ...,
#         [ 55, 129, 151],
#         [ 57, 127, 149],
#         [ 55, 121, 141]],
#
#        [[ 94, 129, 144],
#         [ 89, 118, 137],
#         [148, 149, 157],
#         ...,
#         [ 56, 133, 154],
#         [ 56, 129, 151],
#         [ 53, 122, 142]],
#
#        [[ 48,  81,  94],
#         [ 71,  98, 108],
#         [155, 142, 149],
#         ...,
#         [ 51, 120, 141],
#         [ 50, 114, 135],
#         [ 48, 108, 125]],
#
#        ...,
#
#        [[ 28,  38,  53],
#         [ 18,  22,  31],
#         [ 33,  47,  61],
#         ...,
#         [158, 122,  95],
#         [151, 116,  90],
#         [150, 115,  87]],
#
#        [[ 38,  61,  86],
#         [ 29,  39,  56],
#         [ 24,  28,  38],
#         ...,
#         [150, 116,  89],
#         [142, 109,  84],
#         [142, 110,  84]],
#
#        [[ 39,  65,  92],
#         [ 37,  63,  89],
#         [ 39,  51,  75],
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
gausblurimg= cv2.GaussianBlur(image,(21,21),0)

# %%
cv2.imwrite('/content/gdrive/My Drive/resizetigerblur.jpg', gausblurimg)
# Out:
# True

# %%
cv2.imwrite('/content/gdrive/My Drive/resizetiger.jpg', resizeimg)
# Out:
# True

# %%
#save an image
cv2.imwrite('resizetiger.jpg',resizeimg)
# Out:
# True
